# %% [markdown]
# Туториал по запуску Stanford NLP
# https://towardsdatascience.com/natural-language-processing-using-stanfords-corenlp-d9e64c1e1024

# %%
from pycorenlp import StanfordCoreNLP
import pandas as pd
import re
from tqdm import tqdm
import spacy
import json

# %%
reviews = pd.read_csv('reviews.csv', sep='\t')

# %%
ids = reviews['id'].unique().tolist()

# %% [markdown]
# Бьем тексты на предложения, потому что CoreNLP не обрабатывает слишком длинные тексты.

# %%
nlp = spacy.load("en_core_web_sm")

# %%
hotels = {}
for id_ in tqdm(ids):
    texts = reviews[reviews['id'] == id_]['reviews.text'].tolist()
    texts_splitted = []
    for text in texts:
        text = nlp(text)
        texts_splitted.extend(list(text.sents))
    hotels[id_] = texts_splitted
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2197/2197 [03:51<00:00,  9.50it/s]

# %%
counter = 0
for key in hotels.keys():
    texts = hotels[key]
    for text in texts:
        if str(text).endswith('...More')or(str(text) == 'More'):
            counter += 1
            print(text)
# Out:
# More
# We...More
# More
# Hotel also has...More
# More
# More
# More
# We look forward to your...More
# More
# We are happy to hear you were provided with friendly and helpful service and appreciate the acknowledgement of...More
# More
# More
# More
# More
# and...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# when I...More
# More
# Joy, Jillian and I are always pleased to assist you in any way and look forward to seeing you again in the...More
# More
# More
# More
# And even though...More
# More
# More
# More
# Thank you for your...More
# More
# More
# All...More
# More
# As you were able to see, we are located in the ideal location for those families who...More
# Eden Roc...More
# I am happy that you enjoyed your...More
# More
# More
# More
# We hope you were able to take advantage of our...More
# More
# More
# More
# ...More
# More
# More
# More
# More
# More
# More
# The front lobby is not quite as exquisite as The Four Seasons, so if that is...More
# More
# More
# More
# More
# More
# More
# More
# It...More
# More
# More
# Skipping on breakfasts, however,...More
# More
# After this trouble, I felt, that this hotel is very nice, well...More
# More
# My single small...More
# More
# More
# More
# More
# More
# More
# Much to...More
# More
# More
# More
# More
# More
# We will address your comments with our...More
# The tv in...More
# We got checked in, car valet'ed and immediately went out to explore downtown, making our way to Drake Park where...More
# More
# More
# More
# More
# More
# More
# More
# Not only was the post by the...More
# More
# NICE HOT breakfast with lots of...More
# This location is...More
# Such a...More
# More
# More
# (no...More
# and INCLUSIVE LIQUIDS!!!Considering the price for Your room includes al of the...More
# More
# The hotel was clean, modern, and an...More
# More
# More
# More
# Brian...More
# This place is always clean and...More
# More
# The food wasn't great - a lot of mushy pasta at dinner - baked potatoes were good but the...More
# More
# More
# More
# More
# Our room was 15 feet from the white sand beach and the view is one of the most breathtaking I have seen, even compared to...More
# Warren pub is...More
# At the registration desk,...More
# More
# More
# More
# More
# But when we got to our amazing room 2nd floor room with an incredible ocean view of Haystack Rock and found...More
# They made our honeymoon extra special with a little...More
# More
# Your...More
# More
# More
# More
# More
# More
# Thats a...More
# More
# More
# More
# More
# More
# We really appreciate the...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# The pool is small and...More
# More
# Comfy beds, enough room for 3 of us, nice little...More
# More
# More
# More
# The location of the hotel was far enough from the...More
# More
# More
# ...More
# It is a pleasure to...More
# Couldn't spend much time on the lanai because of...More
# Mahalo for...More
# More
# More
# More
# More
# More
# We...More
# ...More
# More
# We appreciate your valuable feedback and will...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# and I'm glad that our team were able to accommodate your requests in every...More
# More
# They even...More
# More
# From time to...More
# More
# More
# More
# More
# More
# I am glad to hear that you enjoyed your most recent visit with us and that you found your...More
# More
# More
# Mahalo, Sunny...More
# Each room has a Duke Kahanamoku lamp and other Hawaiian decor which adds to the ambiance of...More
# ...More
# More
# More
# Likewise, most attractions, including the Ala Moana Mall, Fort...More
# More
# More
# we...More
# Small refrigerator but some rooms don't have microwave (only...More
# More
# We are replacing our elevators one at a time and are excited to say that our new and...More
# More
# More
# Mahalo for the...More
# We are glad that you found our location to be an excellent one and, most importantly, we...More
# Right on the...More
# More
# More
# More
# More
# I am glad that you enjoyed our signature amenities and...More
# More
# and we hope that you have the opportunity to experience our...More
# More
# Just below our...More
# More
# Thank you for staying with us and we look forward to personalizing your...More
# More
# More
# Mahalo for also sharing some...More
# More
# More
# More
# We sincerely apologize for any...More
# More
# More
# More
# The location is close to the...More
# On...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# I would like to sincerely apologize for the inconveniences that you have experienced throughout your visit here at the...More
# More
# More
# if you don't spend a lot of time in the...More
# More
# More
# ...More
# More
# More
# Please accept our sincere apology for the...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# we unexpectedly extended our stay and they told us the room needed new furniture and they updated us to a...More
# More
# I am...More
# Thank you for the kind comments regarding...More
# More
# More
# More
# I hope that when you return to the east coast and Orlando that you will...More
# More
# More
# More
# We were...More
# More
# There is a designated smoking section on property in the courtyard which is landscaped with trees and...More
# Next time you are with us, be sure to check out the...More
# More
# More
# The only thing that was...More
# It has an...More
# More
# More
# More
# and...More
# More
# More
# Many of our guests also enjoy how...More
# More
# More
# More
# More
# More
# More
# We really appreciate your recommendation and will...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# Please check out our room packages HOLO HOLO which is...More
# More
# Housekeeping upholds high standards to keep the...More
# More
# More
# Whether for one night or one month, our spacious suites are set up so that you always feel at home even when you're on the...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# We are also...More
# More
# More
# More
# More
# More
# More
# More
# Customer service is...More
# We greatly value your feedback and...More
# More
# We would like to speak with you on how...More
# More
# Aside from that minor inconvenience, I...More
# More
# We are thrilled that you enjoyed our...More
# More
# We...More
# More
# Our goal at Sonesta Resort Hilton Head is to always provide a memorable experience for each guest, so we are very pleased to hear that you had the chance to experience our...More
# More
# More
# ...More
# More
# More
# Customer service is very important to us, so I am delighted that our staff...More
# We...More
# More
# However, every time we have stayed...More
# Our proximity to LAX and our complimentary shuttle service to and from the airport make us a great choice to those with a...More
# Pretty...More
# The room was a...More
# More
# More
# The thin...More
# only 1...More
# More
# With opening a new hotel there...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# Thanks again for the great review, we will see you on your...More
# I apologies that the local convenience stores had closed up for the...More
# More
# More
# More
# More
# More
# ...More
# if...More
# More
# More
# More
# We hope you can consider our hotel for...More
# More
# More
# More
# More
# More
# More
# Also the location was very convenient to attractions and the information counter in the...More
# More
# More
# Hotel staff at front desk was not helpful and had a...More
# More
# More
# The room was not expensive and we had a...More
# More
# More
# I have addressed your...More
# More
# More
# More
# More
# More
# Please know the conditions you describe are an exception to our guest commitment and as such, we apologize for the...More
# More
# And last but not...More
# More
# More
# There's an interesting restaurant and bar on the premises as well...More
# The rooms are...More
# More
# More
# More
# More
# people probably...More
# More
# More
# More
# Architectural reverence' is a great way to describe the care and effort that went into making Hotel Emma what...More
# We had a...More
# More
# More
# and...More
# More
# We were able to check in early upon arriving, and were...More
# More
# More
# ...More
# They did a fantastic job of maintaining the history of...More
# More
# The area around the hotel is full of interesting places to check out, and the...More
# More
# More
# More
# More
# More
# From the surprise complimentary champagne awaiting us in our lovely room, to Tim the bellhop, Jenny who delivered our drinks and snacks in the Sternewirth bar, the complimentary car service to our first night's dinner at the Plaza Club, through the excellence of the cleaning...More
# you can take a river boat ride and enjoy the...More
# The rooms are...More
# From impeccably cleaned rooms, turndown service, and...More
# to the absolutely lovely room to...More
# More
# More
# More
# More
# More
# More
# More
# In order to provide complete transparency to other readers and future...More
# Your description...More
# I've stayed at plenty of 5 star hotels around the country and even internationally, and Hotel Emma is at the top of...More
# More
# More
# More
# On...More
# More
# The River Walk paths around the...More
# More
# More
# More
# More
# Everything is perfect from the linens and towels to...More
# More
# Sincerely, Jamie Fox...More
# As other reviews state, the extras are a...More
# but there was the lovely pool to relax by and the complimentary cupcakes to eat and the...More
# We enjoyed being out of the city and the...More
# More
# More
# ...More
# More
# More
# Loved the rooms and...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# ...More
# More
# From the welcome drink through check out, the...More
# More
# More
# More
# The...More
# More
# More
# Our stay was for our first wedding anniversary and the manager and staff of Hotel Emma went out of their way to make it special - from the welcome card/champagne in the lovely room to the delicious dinner and complimentary dessert and finally to a...More
# More
# a...More
# More
# More
# More
# The best part is the...More
# More
# More
# More
# More
# More
# More
# More
# We...More
# More
# We...More
# but...More
# More
# We...More
# More
# More
# More
# More
# More
# More
# Loved it even more that you noticed some of the little things we do to set us a part from the...More
# More
# In regards to the service, food quality poolside atmosphere you experienced, I can assure you that they...More
# We love creating loyal guests, and...More
# They are...More
# More
# More
# More
# In regards to the themed rooms, ZaZa has a colorful collection of Concept Magnificent suites that are a...More
# More
# More
# More
# More
# More
# More
# We love to celebrate feedback like yours as a team and will make sure each one of...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# and...More
# More
# We...More
# More
# More
# More
# Also, half...More
# More
# We've shared your compliments with the...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# It was...More
# More
# More
# More
# More
# ...More
# More
# More
# More
# More
# More
# More
# More
# You may want to ask for a room facing away from the highway, I have been told that this...More
# It...More
# and...More
# More
# Was able to get a...More
# Traffic pattern for the...More
# The motel is about a 10 minute drive to the Joshua Tree visitor centre, whilst a 10 minute drive in the opposite direction will take you to Yucca Valley where there are...More
# More
# More
# More
# More
# More
# More
# More
# We...More
# More
# It will be my honor to pass on your kind words to...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# I am not affiliated as a shareholder, supplier, or otherwise with any of...More
# More
# More
# This man in a grey suit practically took the keys out of our hand and was...More
# It...More
# More
# More
# More
# More
# I sincerely apologize that we did not live up to your...More
# More
# We were also treated with 4...More
# More
# More
# More
# The Ritz provides the coffee pods, but ask at the front desk for creamers if...More
# For that first...More
# More
# More
# ...More
# ...More
# More
# We did stay in a premier room, which...More
# More
# More
# More
# More
# More
# More
# On a side note for...More
# More
# More
# More
# arranged by the...More
# More
# When I confirmed with the Indian that it was indeed slow, I...More
# More
# More
# More
# There is no service in the conference area but there...More
# More
# From the valet parking attendants...More
# More
# More
# More
# More
# ...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# The hotel was...More
# Therefore I will pick a...More
# More
# More
# More
# We were coming off a stay at a Four Seasons that was exceptional so that...More
# I am a Platinum rewards member and this was...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# We booked connecting rooms and ordered cots for the boys which...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# Until next...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# We stayed in a Junior Suite which had a...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# The free breakfast buffet is an amazing value, especially considering the price of...More
# and...More
# More
# More
# More
# More
# Sincerely, Jason...More
# More
# More
# More
# More
# More
# More
# More
# Our free breakfast does offer...More
# More
# More
# For future reference, please...More
# More
# More
# More
# More
# More
# The owners, Susie and...More
# More
# More
# More
# Every time I touched...More
# More
# More
# Hot tub was never busy and set under a pretty mosaic of a...More
# All of the staff is amazingly friendly, the rooms are clean, the location is amazing right on Duval Street where all of the action is, but on the quiet end so no endless parties outside your...More
# Our first...More
# More
# More
# The exterior is...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# but it was off the...More
# More
# The bartender was a little unfriendly and seemed bored with his...More
# More
# More
# More
# More
# More
# More
# My husband has...More
# We...More
# We had originally booked at a large beach front resort but opted out at the last minute for something a little...More
# I loved the bed and if...More
# More
# And the woman tending bar...More
# More
# More
# More
# More
# More
# Inside the room though it is...More
# Keep a light...More
# More
# More
# , should you...More
# The staff was super helpful beginning with an email I sent prior to my arrival, to great recommendations at check in and...More
# More
# Like I said, there are...More
# More
# A...More
# More
# More
# The hotel location is PERFECT at Duval and Truman close enough for the craziness and...More
# More
# The complimentary breakfast had a wide spread, the complimentary drink every evening was...More
# More
# More
# More
# If you want a hotel that is on Duval and close to the action but not right in it, If you want a hotel that is friendly and helpful if you want a hotel which has happy hour if you want a hotel with a...More
# More
# Wake up to a...More
# More
# More
# More
# ...More
# More
# More
# More
# We remodel frequently and are...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# Rooms were very nice and the...More
# More
# More
# More
# More
# More
# More
# this particular hotel gets a solid 5 star rating from my...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# Shane and...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# When we pull up to...More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More
# More

# %%
counter
# Out:
# 884

# %% [markdown]
# Предложения в основном рубленые, визуально особо важной  информации в них нет. Удаляем их.

# %%
for key in hotels.keys():
    texts = hotels[key]
    texts_clean = []
    for text in texts:
        if (not str(text).endswith('...More'))and(str(text) != 'More'):
            texts_clean.append(str(text))
    hotels[key] = texts_clean

# %%
#with open('hotel_sentences.json', 'w', encoding='utf-8') as f:
#    f.write(json.dumps(hotels))

# %% [markdown]
# Обработка CoreNLP, получение деревьев.

# %%
# !java -mx6g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -timeout 5000
# Out:
# ^C

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
hotel_trees = {}

# %%
for id_ in tqdm(list(hotels.keys())):
    trees = []
    texts = hotels[id_]
    for text in texts:
        result = nlp.annotate(text,
                           properties={
                               'annotators': 'sentiment',
                               'outputFormat': 'json',
                               'timeout': 10000,
                           })
        if result == 'CoreNLP request timed out. Your document may be too long.':
            # слишком длинные предложения бьем по запятой
            text = text.split(',')
            for part in text:
                result = nlp.annotate(part,
                           properties={
                               'annotators': 'sentiment',
                               'outputFormat': 'json',
                               'timeout': 10000,
                           })
                # если и часть не получается, пропускаем
                if result == 'CoreNLP request timed out. Your document may be too long.':
                    continue
                for sent in result['sentences']:
                    trees.append(sent['sentimentTree'])
        else:
            for sent in result['sentences']:
                trees.append(sent['sentimentTree'])
    hotel_trees[id_] = trees
# Out:
#   3%|██▍                                                                           | 69/2197 [15:13<7:49:22, 13.23s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-ebca50875541> in <module>
#       3     texts = hotels[id_]
#       4     for text in texts:
# ----> 5         result = nlp.annotate(text,
#       6                            properties={
#       7                                'annotators': 'sentiment',
#
# ~\anaconda3\lib\site-packages\pycorenlp\corenlp.py in annotate(self, text, properties)
#      24
#      25         data = text.encode()
# ---> 26         r = requests.post(
#      27             self.server_url, params={
#      28                 'properties': str(properties)
#
# ~\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#hotel_trees_json = json.dumps(hotel_trees)
#with open('hotel_trees.json', 'w', encoding='utf-8') as f:
#    f.write(hotel_trees_json)

# %% [markdown]
# Чистим деревья.

# %%
with open('hotel_trees.json', 'r', encoding='utf-8') as f:
    hotel_trees_json = f.read()
hotel_trees = json.loads(hotel_trees_json)

# %%
for key in hotel_trees.keys():
    trees = hotel_trees[key]
    trees_cleaned = []
    for tree in trees:
        tree = re.sub('\\r\\n', '', tree)
        tree = re.sub('\s+', ' ', tree)
        trees_cleaned.append(tree)
    hotel_trees[key] = trees_cleaned

# %%
hotel_trees['AVwc252WIN2L1WUfpqLP']
# Out:
# ['(ROOT|sentiment=3|prob=0,549 (@S|sentiment=3|prob=0,499 (NP|sentiment=2|prob=0,972 (NP|sentiment=2|prob=0,980 (PRP$|sentiment=2|prob=0,993 Our) (NN|sentiment=2|prob=0,995 experience)) (PP|sentiment=2|prob=1,000 (IN|sentiment=2|prob=0,997 at) (NP|sentiment=2|prob=0,528 (NNP|sentiment=2|prob=0,625 Rancho) (NNP|sentiment=2|prob=0,625 Valencia)))) (VP|sentiment=3|prob=0,607 (VBD|sentiment=2|prob=0,997 was) (ADJP|sentiment=3|prob=0,661 (RB|sentiment=3|prob=0,970 absolutely) (@ADJP|sentiment=3|prob=0,621 (JJ|sentiment=4|prob=0,950 perfect) (PP|sentiment=2|prob=0,798 (IN|sentiment=2|prob=1,000 from) (S|sentiment=2|prob=0,731 (VBG|sentiment=2|prob=0,997 beginning) (S|sentiment=2|prob=1,000 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=0,999 end)))))))) (.|sentiment=2|prob=0,625 !!!!))',
#  '(ROOT|sentiment=3|prob=0,500 (@S|sentiment=3|prob=0,604 (NP|sentiment=2|prob=0,999 We) (VP|sentiment=3|prob=0,589 (@VP|sentiment=3|prob=0,734 (VBD|sentiment=2|prob=0,998 felt) (ADJP|sentiment=3|prob=0,931 (@ADJP|sentiment=2|prob=1,000 (ADJP|sentiment=3|prob=0,967 special) (CC|sentiment=2|prob=0,998 and)) (ADJP|sentiment=4|prob=0,711 (RB|sentiment=2|prob=0,996 very) (JJ|sentiment=4|prob=0,928 happy)))) (PP|sentiment=3|prob=0,993 (IN|sentiment=2|prob=0,999 during) (NP|sentiment=2|prob=0,625 (NP|sentiment=2|prob=0,996 our) (VP|sentiment=2|prob=0,824 stayed))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=2|prob=0,674 (@S|sentiment=2|prob=0,708 (NP|sentiment=2|prob=1,000 I) (VP|sentiment=2|prob=0,715 (MD|sentiment=2|prob=0,995 would) (VP|sentiment=2|prob=0,675 (@VP|sentiment=2|prob=1,000 (VB|sentiment=2|prob=0,999 come) (ADVP|sentiment=2|prob=0,998 back)) (PP|sentiment=3|prob=0,577 (IN|sentiment=2|prob=0,999 in) (NP|sentiment=3|prob=0,739 (NP|sentiment=3|prob=0,835 (DT|sentiment=2|prob=0,998 a) (NN|sentiment=2|prob=0,990 heart)) (SBAR|sentiment=2|prob=0,994 beat)))))) (.|sentiment=2|prob=0,625 !!))',
#  '(ROOT|sentiment=2|prob=0,998 !)',
#  '(ROOT|sentiment=4|prob=0,795 (@NP|sentiment=4|prob=0,978 (JJ|sentiment=4|prob=0,933 Amazing) (NN|sentiment=2|prob=0,995 place)) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=3|prob=0,500 (@S|sentiment=3|prob=0,499 (NP|sentiment=2|prob=0,999 Everyone) (VP|sentiment=3|prob=0,512 (VBD|sentiment=2|prob=0,997 was) (ADJP|sentiment=3|prob=0,606 (RB|sentiment=2|prob=0,990 extremely) (@ADJP|sentiment=3|prob=0,636 (@ADJP|sentiment=2|prob=0,924 (JJ|sentiment=3|prob=0,975 warm) (CC|sentiment=2|prob=0,998 and)) (JJ|sentiment=2|prob=0,625 welcoming))))) (.|sentiment=2|prob=1,000 .))',
#  "(ROOT|sentiment=3|prob=0,503 (@S|sentiment=3|prob=0,500 (@S|sentiment=3|prob=0,501 (S|sentiment=3|prob=0,501 (NP|sentiment=2|prob=0,999 We) (VP|sentiment=3|prob=0,407 (VBP|sentiment=2|prob=0,999 've) (VP|sentiment=3|prob=0,609 (VBN|sentiment=2|prob=0,824 stayed) (PP|sentiment=2|prob=0,551 (IN|sentiment=2|prob=0,997 at) (NP|sentiment=3|prob=0,743 (DT|sentiment=2|prob=0,999 some) (@NP|sentiment=3|prob=0,870 (NML|sentiment=2|prob=0,984 (JJ|sentiment=2|prob=0,990 top) (NN|sentiment=2|prob=0,971 notch)) (NNS|sentiment=2|prob=0,996 places))))))) (CC|sentiment=2|prob=0,998 and)) (S|sentiment=3|prob=0,665 (NP|sentiment=2|prob=0,998 this) (VP|sentiment=3|prob=0,647 (@VP|sentiment=2|prob=0,994 (VBZ|sentiment=2|prob=0,999 is) (ADVP|sentiment=3|prob=0,988 definitely)) (PP|sentiment=2|prob=0,509 (IN|sentiment=2|prob=0,999 in) (NP|sentiment=3|prob=0,858 (PRP$|sentiment=2|prob=0,996 our) (NML|sentiment=3|prob=0,661 (JJ|sentiment=2|prob=0,990 top) (CD|sentiment=2|prob=0,997 2))))))) (.|sentiment=2|prob=1,000 .))",
#  '(ROOT|sentiment=3|prob=0,474 (UCP|sentiment=3|prob=0,472 (@UCP|sentiment=3|prob=0,496 (ADJP|sentiment=3|prob=0,633 (JJ|sentiment=4|prob=0,886 Great) (PP|sentiment=2|prob=0,798 (IN|sentiment=2|prob=0,998 for) (NP|sentiment=2|prob=0,797 (DT|sentiment=2|prob=0,998 a) (@NP|sentiment=2|prob=0,996 (JJ|sentiment=2|prob=0,980 romantic) (NN|sentiment=2|prob=0,625 getaway))))) (CC|sentiment=2|prob=0,998 or)) (S|sentiment=2|prob=0,591 (@VP|sentiment=2|prob=0,995 (VB|sentiment=2|prob=0,999 take) (NP|sentiment=2|prob=1,000 (DT|sentiment=2|prob=0,999 the) (NNS|sentiment=2|prob=0,992 kids))) (PP|sentiment=2|prob=0,892 (IN|sentiment=2|prob=0,997 along) (SBAR|sentiment=2|prob=0,995 (IN|sentiment=2|prob=0,999 as) (S|sentiment=2|prob=1,000 (NP|sentiment=2|prob=1,000 we) (VP|sentiment=2|prob=0,999 did)))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=2|prob=0,436 (@SINV|sentiment=2|prob=0,591 (@SINV|sentiment=2|prob=0,994 (VBD|sentiment=2|prob=0,992 Had) (NP|sentiment=2|prob=1,000 (DT|sentiment=2|prob=0,998 a) (NN|sentiment=2|prob=0,994 couple))) (VP|sentiment=2|prob=0,693 (VBN|sentiment=2|prob=0,987 stuffed) (NP|sentiment=2|prob=0,792 (NP|sentiment=2|prob=0,988 animals) (VP|sentiment=2|prob=0,802 (@VP|sentiment=2|prob=0,945 (VBG|sentiment=2|prob=0,998 waiting) (PP|sentiment=2|prob=0,999 (IN|sentiment=2|prob=0,998 for) (NP|sentiment=2|prob=1,000 (PRP$|sentiment=2|prob=0,996 our) (NNS|sentiment=2|prob=0,998 girls)))) (PP|sentiment=2|prob=0,999 (IN|sentiment=2|prob=0,998 upon) (NP|sentiment=2|prob=0,625 arrival)))))) (.|sentiment=2|prob=1,000 .))',
#  "(ROOT|sentiment=2|prob=0,564 (VP|sentiment=2|prob=0,745 (@VP|sentiment=2|prob=1,000 (MD|sentiment=2|prob=0,995 Ca) (RB|sentiment=2|prob=0,997 n't)) (VP|sentiment=2|prob=0,719 (VB|sentiment=2|prob=0,998 wait) (S|sentiment=2|prob=0,929 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=1,000 (VB|sentiment=2|prob=0,999 go) (ADVP|sentiment=2|prob=0,998 back))))) (.|sentiment=2|prob=1,000 .))",
#  '(ROOT|sentiment=2|prob=0,365 (@S|sentiment=2|prob=0,349 (NP|sentiment=2|prob=0,999 We) (VP|sentiment=2|prob=0,349 (@VP|sentiment=2|prob=0,560 (@VP|sentiment=2|prob=0,494 (@VP|sentiment=2|prob=0,576 (VBD|sentiment=2|prob=0,625 booked) (NP|sentiment=2|prob=0,591 (NP|sentiment=2|prob=0,593 (DT|sentiment=2|prob=0,998 a) (@NP|sentiment=2|prob=0,521 (NML|sentiment=3|prob=0,513 (CD|sentiment=2|prob=0,990 3) (NN|sentiment=2|prob=0,993 night)) (NN|sentiment=2|prob=0,985 stay))) (PP|sentiment=2|prob=1,000 (IN|sentiment=2|prob=0,997 at) (NP|sentiment=2|prob=0,528 (NNP|sentiment=2|prob=0,625 Rancho) (NNP|sentiment=2|prob=0,625 Valencia))))) (S|sentiment=2|prob=0,798 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=0,855 (VB|sentiment=2|prob=0,995 play) (NP|sentiment=2|prob=0,926 (DT|sentiment=2|prob=0,999 some) (NN|sentiment=2|prob=0,625 tennis))))) (,|sentiment=2|prob=1,000 ,)) (SBAR|sentiment=2|prob=0,519 (IN|sentiment=2|prob=0,998 since) (S|sentiment=2|prob=0,499 (NP|sentiment=2|prob=1,000 it) (VP|sentiment=2|prob=0,524 (VBZ|sentiment=2|prob=0,999 is) (NP|sentiment=2|prob=0,719 (NP|sentiment=2|prob=0,999 one) (PP|sentiment=2|prob=0,798 (IN|sentiment=2|prob=1,000 of) (NP|sentiment=2|prob=0,804 (NP|sentiment=3|prob=0,682 (DT|sentiment=2|prob=0,999 the) (@NP|sentiment=3|prob=0,653 (ADJP|sentiment=3|prob=0,903 (JJS|sentiment=2|prob=0,982 highest) (VBN|sentiment=2|prob=0,969 rated)) (@NP|sentiment=2|prob=0,989 (NN|sentiment=2|prob=0,625 tennis) (NNS|sentiment=2|prob=0,996 resorts)))) (PP|sentiment=2|prob=0,996 (IN|sentiment=2|prob=0,999 in) (NP|sentiment=2|prob=0,996 America)))))))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=2|prob=0,351 (@S|sentiment=2|prob=0,492 (NP|sentiment=2|prob=0,995 (DT|sentiment=2|prob=0,999 This) (NN|sentiment=2|prob=0,995 place)) (VP|sentiment=2|prob=0,591 (@VP|sentiment=2|prob=1,000 (VBZ|sentiment=2|prob=0,999 is) (ADVP|sentiment=2|prob=0,999 really)) (PP|sentiment=2|prob=0,756 (IN|sentiment=2|prob=0,995 over) (NP|sentiment=2|prob=0,675 (NP|sentiment=2|prob=0,750 (DT|sentiment=2|prob=0,999 the) (NN|sentiment=2|prob=0,990 top)) (PP|sentiment=2|prob=0,805 (IN|sentiment=2|prob=1,000 from) (NP|sentiment=2|prob=0,671 (@NP|sentiment=2|prob=0,967 (NP|sentiment=2|prob=0,998 (DT|sentiment=2|prob=0,998 a) (@NP|sentiment=2|prob=0,528 (NN|sentiment=2|prob=0,625 luxury) (NN|sentiment=2|prob=0,625 standpoint))) (CC|sentiment=2|prob=0,998 and)) (NP|sentiment=2|prob=0,999 (JJ|sentiment=2|prob=0,995 overall) (NN|sentiment=2|prob=0,995 experience)))))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=3|prob=0,558 (@S|sentiment=4|prob=0,502 (@S|sentiment=3|prob=0,589 (@S|sentiment=3|prob=0,589 (@S|sentiment=4|prob=0,502 (@S|sentiment=3|prob=0,538 (S|sentiment=4|prob=0,513 (NP|sentiment=2|prob=0,944 (DT|sentiment=2|prob=0,999 The) (NNS|sentiment=2|prob=0,625 villas)) (VP|sentiment=4|prob=0,647 (VBP|sentiment=2|prob=0,999 are) (ADJP|sentiment=4|prob=0,983 (RB|sentiment=2|prob=0,999 really) (JJ|sentiment=4|prob=0,950 perfect)))) (,|sentiment=2|prob=1,000 ,)) (S|sentiment=3|prob=0,499 (NP|sentiment=2|prob=0,995 (DT|sentiment=2|prob=0,999 the) (NN|sentiment=2|prob=0,625 staff)) (VP|sentiment=4|prob=0,502 (@VP|sentiment=3|prob=0,589 (@VP|sentiment=3|prob=0,590 (@VP|sentiment=4|prob=0,551 (VBZ|sentiment=2|prob=0,999 is) (ADJP|sentiment=4|prob=0,964 great)) (,|sentiment=2|prob=1,000 ,)) (NP|sentiment=2|prob=0,997 attention)) (PP|sentiment=3|prob=0,499 (IN|sentiment=2|prob=0,999 to) (NP|sentiment=4|prob=0,502 (@NP|sentiment=3|prob=0,555 (@NP|sentiment=3|prob=0,603 (NP|sentiment=2|prob=0,993 details) (PRN|sentiment=3|prob=0,498 (@PRN|sentiment=3|prob=0,504 (-LRB-|sentiment=2|prob=1,000 -LRB-) (S|sentiment=3|prob=0,615 (VBZ|sentiment=2|prob=0,994 includes) (NP|sentiment=3|prob=0,640 (NP|sentiment=4|prob=0,898 fresh) (VP|sentiment=2|prob=0,801 (@VP|sentiment=2|prob=0,995 (VBN|sentiment=2|prob=0,973 squeezed) (NP|sentiment=2|prob=1,000 (NN|sentiment=2|prob=0,988 orange) (NN|sentiment=2|prob=0,990 juice))) (NP-TMP|sentiment=2|prob=1,000 (DT|sentiment=2|prob=0,996 each) (NN|sentiment=2|prob=0,998 morning)))))) (-RRB-|sentiment=2|prob=0,997 -RRB-))) (,|sentiment=2|prob=1,000 ,)) (UCP|sentiment=3|prob=0,501 (NML|sentiment=2|prob=0,625 restaurants) (@UCP|sentiment=3|prob=0,644 (,|sentiment=2|prob=1,000 ,) (@UCP|sentiment=3|prob=0,614 (@UCP|sentiment=2|prob=1,000 (NML|sentiment=2|prob=0,991 bar) (CC|sentiment=2|prob=0,998 and)) (ADJP|sentiment=4|prob=0,537 (NP|sentiment=2|prob=0,998 (NN|sentiment=2|prob=0,996 room) (NN|sentiment=2|prob=0,995 service)) (JJ|sentiment=4|prob=0,935 amazing)))))))))) (,|sentiment=2|prob=1,000 ,)) (CC|sentiment=2|prob=0,998 and)) (S|sentiment=3|prob=0,577 (NP|sentiment=2|prob=0,998 (DT|sentiment=2|prob=0,999 the) (@NP|sentiment=3|prob=0,699 (NN|sentiment=2|prob=0,625 tennis) (NN|sentiment=2|prob=0,972 program))) (VP|sentiment=3|prob=0,590 (@VP|sentiment=3|prob=0,685 (VBD|sentiment=2|prob=0,997 was) (ADJP|sentiment=4|prob=0,852 (RB|sentiment=2|prob=0,999 really) (JJ|sentiment=4|prob=0,921 impressive))) (ADVP|sentiment=2|prob=0,915 (RB|sentiment=2|prob=0,999 as) (RB|sentiment=3|prob=0,985 well))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=3|prob=0,511 (@S|sentiment=2|prob=0,528 (NP|sentiment=2|prob=0,999 We) (VP|sentiment=2|prob=0,550 (MD|sentiment=2|prob=0,999 will) (VP|sentiment=2|prob=0,676 (VB|sentiment=2|prob=0,999 want) (S|sentiment=2|prob=0,681 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=0,686 (@VP|sentiment=2|prob=0,961 (VB|sentiment=2|prob=0,999 come) (ADVP|sentiment=2|prob=1,000 (RB|sentiment=2|prob=0,998 back) (RB|sentiment=2|prob=1,000 here))) (ADVP|sentiment=2|prob=0,999 again)))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=3|prob=0,521 (@S|sentiment=3|prob=0,506 (NP|sentiment=2|prob=0,675 (NP|sentiment=2|prob=0,982 (DT|sentiment=2|prob=0,999 The) (NN|sentiment=2|prob=0,995 experience)) (PP|sentiment=2|prob=0,951 (IN|sentiment=2|prob=0,997 at) (NP|sentiment=2|prob=0,990 (DT|sentiment=2|prob=0,998 this) (NN|sentiment=2|prob=0,995 place)))) (VP|sentiment=3|prob=0,736 (VBD|sentiment=2|prob=0,997 was) (ADJP|sentiment=4|prob=0,935 amazing))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=1|prob=0,379 (@S|sentiment=1|prob=0,421 (SBAR|sentiment=2|prob=0,514 (IN|sentiment=2|prob=0,999 Although) (S|sentiment=1|prob=0,442 (NP|sentiment=2|prob=1,000 we) (@S|sentiment=1|prob=0,471 (ADVP|sentiment=2|prob=0,993 only) (VP|sentiment=3|prob=0,346 (@VP|sentiment=2|prob=0,681 (VP|sentiment=2|prob=0,623 (@VP|sentiment=2|prob=0,400 (VBD|sentiment=2|prob=0,824 stayed) (PP|sentiment=2|prob=1,000 (IN|sentiment=2|prob=0,998 for) (NP|sentiment=2|prob=0,999 one))) (NP-TMP|sentiment=2|prob=0,993 night)) (CC|sentiment=2|prob=0,998 and)) (VP|sentiment=2|prob=0,675 (@VP|sentiment=2|prob=0,998 (VBD|sentiment=2|prob=0,999 did) (RB|sentiment=2|prob=0,625 nt)) (VP|sentiment=2|prob=0,788 (VB|sentiment=2|prob=0,999 get) (S|sentiment=2|prob=0,927 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=0,788 (VB|sentiment=2|prob=0,998 do) (NP|sentiment=2|prob=0,999 everything))))))))) (@S|sentiment=2|prob=0,524 (NP|sentiment=2|prob=1,000 it) (VP|sentiment=2|prob=0,569 (MD|sentiment=2|prob=0,989 must) (VP|sentiment=2|prob=0,785 (VB|sentiment=2|prob=0,998 be) (NP|sentiment=2|prob=0,644 (NP|sentiment=2|prob=0,999 one) (PP|sentiment=2|prob=0,681 (IN|sentiment=2|prob=1,000 of) (NP|sentiment=2|prob=0,675 (NP|sentiment=2|prob=0,550 (NP|sentiment=2|prob=0,708 (DT|sentiment=2|prob=0,999 the) (JJS|sentiment=4|prob=0,494 nicest)) (VP|sentiment=2|prob=0,958 (@VP|sentiment=2|prob=0,964 (VBN|sentiment=2|prob=0,995 placed) (NP|sentiment=2|prob=0,625 weve)) (ADVP|sentiment=2|prob=0,999 ever))) (VP|sentiment=2|prob=0,997 been)))))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=3|prob=0,472 (@S|sentiment=2|prob=0,446 (NP|sentiment=2|prob=1,000 It) (VP|sentiment=2|prob=0,514 (@VP|sentiment=2|prob=0,880 (VBZ|sentiment=2|prob=0,999 is) (PP|sentiment=3|prob=0,743 (IN|sentiment=2|prob=0,998 for) (ADJP|sentiment=2|prob=0,996 sure))) (ADJP|sentiment=2|prob=0,641 (ADJP|sentiment=4|prob=0,875 better) (PP|sentiment=2|prob=0,737 (IN|sentiment=2|prob=0,999 than) (NP|sentiment=2|prob=0,591 (NP|sentiment=2|prob=1,000 (DT|sentiment=2|prob=0,999 the) (NML|sentiment=2|prob=0,991 (NNP|sentiment=2|prob=0,997 Four) (NNP|sentiment=2|prob=0,625 Seasons))) (PP|sentiment=2|prob=0,494 (IN|sentiment=2|prob=0,999 in) (NP|sentiment=2|prob=0,494 (NP|sentiment=2|prob=1,000 (NNP|sentiment=2|prob=0,997 Santa) (NNP|sentiment=2|prob=0,989 Barbara)) (SBAR|sentiment=2|prob=0,347 (WHNP|sentiment=2|prob=0,999 which) (S|sentiment=3|prob=0,455 (NP|sentiment=2|prob=1,000 we) (@S|sentiment=3|prob=0,463 (:|sentiment=2|prob=1,000 ...) (@S|sentiment=3|prob=0,462 (NP|sentiment=2|prob=0,528 (NP|sentiment=2|prob=0,625 MoreDear) (NP|sentiment=2|prob=0,625 renderfarmer)) (@S|sentiment=3|prob=0,463 (,|sentiment=2|prob=1,000 ,) (VP|sentiment=3|prob=0,463 (@VP|sentiment=2|prob=0,798 (@VP|sentiment=2|prob=0,880 (VBP|sentiment=2|prob=0,625 Thank) (NP|sentiment=2|prob=0,999 you)) (ADVP|sentiment=2|prob=1,000 (RB|sentiment=2|prob=0,998 so) (RB|sentiment=2|prob=0,998 much))) (PP|sentiment=3|prob=0,588 (IN|sentiment=2|prob=0,998 for) (NP|sentiment=3|prob=0,589 (NP|sentiment=3|prob=0,683 (PRP$|sentiment=2|prob=0,991 your) (@NP|sentiment=4|prob=0,571 (ADJP|sentiment=3|prob=0,564 (@ADJP|sentiment=3|prob=0,946 (JJ|sentiment=3|prob=0,845 gracious) (CC|sentiment=2|prob=0,998 and)) (JJ|sentiment=4|prob=0,928 thoughtful)) (NN|sentiment=2|prob=0,991 review))) (PP|sentiment=2|prob=1,000 (IN|sentiment=2|prob=1,000 of) (NP|sentiment=2|prob=0,528 (NNP|sentiment=2|prob=0,625 Rancho) (NNP|sentiment=2|prob=0,625 Valencia)))))))))))))))))) (.|sentiment=2|prob=0,998 !))',
#  "(ROOT|sentiment=3|prob=0,500 (@S|sentiment=3|prob=0,499 (NP|sentiment=2|prob=0,999 We) (VP|sentiment=3|prob=0,499 (VBP|sentiment=2|prob=0,999 're) (ADJP|sentiment=3|prob=0,512 (JJ|sentiment=3|prob=0,658 thrilled) (S|sentiment=3|prob=0,499 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=3|prob=0,500 (VB|sentiment=2|prob=0,997 hear) (SBAR|sentiment=3|prob=0,500 (@SBAR|sentiment=3|prob=0,504 (SBAR|sentiment=3|prob=0,499 (IN|sentiment=2|prob=0,999 that) (S|sentiment=3|prob=0,499 (NP|sentiment=2|prob=0,999 you) (VP|sentiment=3|prob=0,500 (VBD|sentiment=2|prob=0,998 had) (NP|sentiment=3|prob=0,539 (NP|sentiment=4|prob=0,881 (DT|sentiment=2|prob=0,998 an) (@NP|sentiment=4|prob=0,981 (JJ|sentiment=4|prob=0,935 amazing) (NN|sentiment=2|prob=0,995 experience))) (PP|sentiment=2|prob=0,798 (IN|sentiment=2|prob=1,000 from) (S|sentiment=2|prob=0,731 (VBG|sentiment=2|prob=0,997 beginning) (S|sentiment=2|prob=1,000 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=0,999 end)))))))) (CC|sentiment=2|prob=0,998 and)) (SBAR|sentiment=3|prob=0,665 (IN|sentiment=2|prob=0,999 that) (S|sentiment=3|prob=0,721 (NP|sentiment=2|prob=0,999 you) (VP|sentiment=3|prob=0,717 (VBD|sentiment=3|prob=0,976 enjoyed) (NP|sentiment=2|prob=0,683 (PRP$|sentiment=2|prob=0,996 our) (@NP|sentiment=2|prob=0,672 (NML|sentiment=2|prob=0,888 (@PP|sentiment=2|prob=0,986 (IN|sentiment=2|prob=0,999 in) (HYPH|sentiment=2|prob=0,994 -)) (NP|sentiment=2|prob=0,996 room)) (NNS|sentiment=2|prob=0,625 amenities)))))))))))) (.|sentiment=2|prob=1,000 .))",
#  '(ROOT|sentiment=1|prob=0,471 (NP|sentiment=2|prob=0,999 We) (VP|sentiment=1|prob=0,471 (@VP|sentiment=2|prob=0,987 (MD|sentiment=2|prob=0,999 can) (RB|sentiment=1|prob=0,992 not)) (VP|sentiment=2|prob=0,538 (VB|sentiment=2|prob=0,998 wait) (S|sentiment=2|prob=0,611 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=0,675 (@VP|sentiment=2|prob=0,861 (@VP|sentiment=2|prob=0,995 (VB|sentiment=2|prob=0,999 have) (NP|sentiment=2|prob=0,999 you)) (ADVP|sentiment=2|prob=0,998 back)) (S|sentiment=2|prob=0,767 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=0,839 (@VP|sentiment=2|prob=0,997 (VB|sentiment=2|prob=0,989 visit) (:|sentiment=2|prob=1,000 ...)) (NP|sentiment=2|prob=0,997 More))))))))',
#  '(ROOT|sentiment=3|prob=0,500 (@NP|sentiment=3|prob=0,499 (NP|sentiment=2|prob=0,999 This) (NP|sentiment=3|prob=0,501 (NP|sentiment=2|prob=0,985 (RB|sentiment=2|prob=0,990 maybe) (CD|sentiment=2|prob=0,999 one)) (PP|sentiment=3|prob=0,620 (IN|sentiment=2|prob=1,000 of) (NP|sentiment=3|prob=0,633 (PRP$|sentiment=2|prob=0,993 my) (@NP|sentiment=3|prob=0,560 (JJ|sentiment=3|prob=0,964 new) (@NP|sentiment=2|prob=0,910 (JJ|sentiment=4|prob=0,372 favorite) (NNS|sentiment=2|prob=0,996 places))))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=1|prob=0,400 (@S|sentiment=1|prob=0,471 (NP|sentiment=2|prob=1,000 I) (VP|sentiment=1|prob=0,471 (VBD|sentiment=2|prob=0,990 began) (PP|sentiment=1|prob=0,471 (IN|sentiment=2|prob=0,999 with) (NP|sentiment=1|prob=0,471 (NP|sentiment=1|prob=0,465 (DT|sentiment=2|prob=0,998 a) (@NP|sentiment=2|prob=0,506 (ADJP|sentiment=1|prob=0,660 (VB|sentiment=2|prob=0,998 sit) (RP|sentiment=2|prob=0,998 down)) (NN|sentiment=3|prob=0,833 check))) (PP|sentiment=2|prob=0,606 (IN|sentiment=2|prob=0,999 in) (PP|sentiment=2|prob=0,614 (IN|sentiment=2|prob=0,999 with) (NP|sentiment=2|prob=0,712 (NP|sentiment=2|prob=0,983 choice) (PP|sentiment=2|prob=0,995 (IN|sentiment=2|prob=1,000 of) (NP|sentiment=2|prob=1,000 (@NP|sentiment=2|prob=0,990 (NN|sentiment=2|prob=0,625 cava) (CC|sentiment=2|prob=0,998 or)) (NN|sentiment=2|prob=0,996 tea)))))))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=3|prob=0,570 (@FRAG|sentiment=3|prob=0,577 (NP|sentiment=2|prob=0,923 (PRP$|sentiment=2|prob=0,998 My) (@NP|sentiment=2|prob=0,893 (NN|sentiment=2|prob=0,996 room) (NN|sentiment=2|prob=0,625 wasnt))) (ADJP|sentiment=3|prob=0,665 (JJ|sentiment=2|prob=0,997 ready) (SBAR|sentiment=3|prob=0,665 (IN|sentiment=2|prob=0,998 so) (S|sentiment=3|prob=0,665 (NP|sentiment=2|prob=1,000 (PRP$|sentiment=2|prob=0,993 my) (NN|sentiment=2|prob=0,995 son)) (VP|sentiment=3|prob=0,882 (VBD|sentiment=3|prob=0,976 enjoyed) (NP|sentiment=2|prob=1,000 (DT|sentiment=2|prob=0,999 the) (NN|sentiment=2|prob=0,998 pool))))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=3|prob=0,518 (@S|sentiment=2|prob=0,550 (NP|sentiment=2|prob=0,944 (DT|sentiment=2|prob=0,999 The) (NNS|sentiment=2|prob=0,625 casitas)) (VP|sentiment=2|prob=0,607 (VBD|sentiment=2|prob=0,625 met) (SBAR|sentiment=2|prob=0,680 (VBD|sentiment=2|prob=0,625 exceeded) (NP|sentiment=2|prob=0,998 (DT|sentiment=2|prob=0,998 all) (NNS|sentiment=2|prob=0,988 expectations))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=1|prob=0,400 (@S|sentiment=1|prob=0,471 (NP|sentiment=2|prob=0,944 (DT|sentiment=2|prob=0,999 The) (NN|sentiment=2|prob=0,625 fireplace)) (VP|sentiment=1|prob=0,465 (@VP|sentiment=2|prob=0,825 (VBD|sentiment=2|prob=0,997 was) (ADJP|sentiment=2|prob=0,978 (RB|sentiment=2|prob=0,998 so) (JJ|sentiment=2|prob=0,625 cozy))) (PP|sentiment=1|prob=0,471 (@PP|sentiment=2|prob=0,991 (IN|sentiment=2|prob=0,997 at) (NFP|sentiment=2|prob=1,000 ...)) (NP|sentiment=2|prob=0,468 (@NP|sentiment=2|prob=0,999 (NP|sentiment=2|prob=0,528 (NNP|sentiment=2|prob=0,625 MoreDear) (CD|sentiment=2|prob=0,625 345rg)) (,|sentiment=2|prob=1,000 ,)) (SBAR|sentiment=2|prob=0,498 (@VP|sentiment=2|prob=0,468 (@VP|sentiment=2|prob=0,880 (VBP|sentiment=2|prob=0,625 Thank) (NP|sentiment=2|prob=0,999 you)) (PP|sentiment=2|prob=0,514 (IN|sentiment=2|prob=0,998 for) (NP|sentiment=2|prob=0,498 (NP|sentiment=2|prob=0,544 (PRP$|sentiment=2|prob=0,991 your) (NN|sentiment=2|prob=0,625 feedback)) (PP|sentiment=2|prob=0,465 (IN|sentiment=2|prob=1,000 about) (NP|sentiment=1|prob=0,455 (NP|sentiment=3|prob=0,722 (PRP$|sentiment=2|prob=0,991 your) (NN|sentiment=2|prob=0,985 stay)) (PP|sentiment=2|prob=0,974 (IN|sentiment=2|prob=0,999 with) (NP|sentiment=3|prob=0,979 us))))))) (PP|sentiment=2|prob=1,000 (IN|sentiment=2|prob=0,997 at) (NP|sentiment=2|prob=0,528 (NNP|sentiment=2|prob=0,625 Rancho) (NNP|sentiment=2|prob=0,625 Valencia)))))))) (.|sentiment=2|prob=1,000 .))',
#  "(ROOT|sentiment=3|prob=0,500 (@S|sentiment=3|prob=0,499 (NP|sentiment=2|prob=0,999 We) (VP|sentiment=3|prob=0,499 (VBP|sentiment=2|prob=0,999 're) (ADJP|sentiment=3|prob=0,512 (JJ|sentiment=3|prob=0,658 thrilled) (S|sentiment=3|prob=0,499 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=3|prob=0,534 (VB|sentiment=2|prob=0,997 hear) (SBAR|sentiment=3|prob=0,499 (NP|sentiment=2|prob=0,999 you) (VP|sentiment=3|prob=0,500 (@VP|sentiment=3|prob=0,718 (VBD|sentiment=3|prob=0,976 enjoyed) (NP|sentiment=2|prob=0,682 (DT|sentiment=2|prob=0,999 the) (@NP|sentiment=2|prob=0,671 (NML|sentiment=2|prob=0,944 (IN|sentiment=2|prob=0,999 in) (@NML|sentiment=2|prob=0,998 (HYPH|sentiment=2|prob=0,994 -) (NN|sentiment=2|prob=0,996 room))) (NNS|sentiment=2|prob=0,625 amenities)))) (PP|sentiment=2|prob=0,591 (IN|sentiment=2|prob=0,999 like) (NP|sentiment=2|prob=0,675 (@NP|sentiment=2|prob=0,675 (@NP|sentiment=2|prob=0,675 (@NP|sentiment=2|prob=0,675 (@NP|sentiment=2|prob=0,993 (NP|sentiment=2|prob=0,995 (DT|sentiment=2|prob=0,999 the) (NNP|sentiment=2|prob=0,625 Nespresso)) (,|sentiment=2|prob=1,000 ,)) (NP|sentiment=2|prob=0,866 (JJ|sentiment=2|prob=0,988 orange) (@NP|sentiment=2|prob=0,978 (NN|sentiment=2|prob=0,990 juice) (NN|sentiment=2|prob=0,992 delivery)))) (,|sentiment=2|prob=1,000 ,)) (CC|sentiment=2|prob=0,998 and)) (NP|sentiment=2|prob=0,625 fireplace)))))))))) (.|sentiment=2|prob=0,998 !))",
#  '(ROOT|sentiment=3|prob=0,500 (@S|sentiment=3|prob=0,610 (NP|sentiment=2|prob=0,999 We) (VP|sentiment=3|prob=0,510 (VBP|sentiment=4|prob=0,949 love) (S|sentiment=2|prob=0,591 (TO|sentiment=2|prob=0,999 to) (VP|sentiment=2|prob=0,614 (VB|sentiment=2|prob=0,999 make) (SBAR|sentiment=2|prob=0,591 (NP|sentiment=2|prob=0,774 (PRP$|sentiment=2|prob=0,996 our) (NNS|sentiment=2|prob=0,625 casitas)) (VP|sentiment=2|prob=0,591 (@VP|sentiment=2|prob=0,591 (VBP|sentiment=2|prob=0,999 feel) (PP|sentiment=2|prob=0,736 (IN|sentiment=2|prob=0,999 like) (ADVP|sentiment=2|prob=0,918 (RB|sentiment=2|prob=0,997 home) (RB|sentiment=2|prob=0,996 away)))) (PP|sentiment=2|prob=0,988 (IN|sentiment=2|prob=1,000 from) (NP|sentiment=2|prob=0,997 home)))))))) (.|sentiment=2|prob=1,000 .))',
#  '(ROOT|sentiment=2|prob=0,669 (@NP|sentiment=1|prob=0,561 (NP|sentiment=2|prob=0,999 We) (:|sentiment=2|prob=1,000 ...)) (NP|sentiment=2|prob=0,997 More))']

# %% [markdown]
# Парсим деревья.

# %%
for key in tqdm(hotel_trees.keys()):
    trees = hotel_trees[key]
    groups_total =[]
    for tree in trees:
        groups = [tree]
        for group in groups:
            #  раскрываем внешние скобки
            group = group[1:len(group)-1]
            #  убираем мусор
            group = re.findall('\(.+\)', group)
            if len(group) == 0:
                continue
            elif len(group) > 1:
                print('Regrex error')
                break
            else:
                group = group[0]
            #  добавляем в список все отдельно стоящие пары скобок
            counter = 0
            start_char = 0
            for num, char in enumerate(group):
                if char == '(':
                    counter += 1
                elif char == ')':
                    counter -= 1
                potential_group = group[start_char: num + 1]
                potential_group = potential_group.strip(' ')
                if (counter == 0)and(potential_group.startswith('(')):
                    groups.append(potential_group)
                    start_char = num + 1
        groups_total.extend(groups)
    hotel_trees[key] = groups_total
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2197/2197 [05:59<00:00,  6.11it/s]

# %% [markdown]
# Наконец, выбираем элементы с выраженным сантиментом.

# %%
for key in tqdm(hotel_trees.keys()):
    groups = hotel_trees[key]
    pos = []
    neg = []
    for group in groups:
        #synt = re.findall('^\((.+?)\|sentiment=\d\|', group)[0]
        sentiment = re.findall('^\(.+?\|sentiment=(\d)\|', group)[0]
        sentiment = int(sentiment)
        if sentiment > 2:
            pos.append(group)
        elif sentiment == 1:
            neg.append(group)
    group_dict = {}
    group_dict['pos'] = pos
    group_dict['neg'] = neg
    hotel_trees[key] = group_dict
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2197/2197 [00:10<00:00, 211.53it/s]

# %% [markdown]
# Чистим полученные группы от тегов, оставляем только текст.

# %%
for key in tqdm(hotel_trees.keys()):
    group_dict = hotel_trees[key]
    pos_clean = []
    for group in group_dict['pos']:
        group = re.sub('\(.+?\|sentiment=\d\|prob=\d,\d\d\d |\)', ' ', group)
        group = re.sub('\s+', ' ', group)
        group = group.strip(' ')
        pos_clean.append(group)
    neg_clean = []
    for group in group_dict['neg']:
        group = re.sub('\(.+?\|sentiment=\d\|prob=\d,\d\d\d |\)', ' ', group)
        group = re.sub('\s+', ' ', group)
        group = group.strip(' ')
        neg_clean.append(group)
    group_dict['pos'] = pos_clean
    group_dict['neg'] = neg_clean
    hotel_trees[key] = group_dict
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2197/2197 [00:09<00:00, 222.55it/s]

# %%
with open('keywords.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(hotel_trees))

# %%
#with open('keywords_NP.json', 'w', encoding='utf-8') as f:
#    f.write(json.dumps(hotel_trees))

# %%
text = reviews['reviews.text'].tolist()[1]

# %%
result = nlp.annotate(text,
                       properties={
                           'annotators': 'sentiment',
                           'outputFormat': 'json',
                           'timeout': 1000,
                       })

# %%
print(result['sentences'][0]['sentimentTree'])
# Out:
# (ROOT|sentiment=4|prob=0,795
#   (@NP|sentiment=4|prob=0,978 (JJ|sentiment=4|prob=0,933 Amazing) (NN|sentiment=2|prob=0,995 place))
#   (.|sentiment=2|prob=1,000 .))
